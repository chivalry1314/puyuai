# %% [markdown]
# 安装openxlab

# %%
pip install openxlab -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 升级openxlab

# %%
pip install -U openxlab
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 进行登录，输入对应的AK/SK

# %%
import openxlab
openxlab.login(ak="r2dnm3v7j89kewvp4k9g", sk="e9kz4kgajypmgyz8yd7ko2xwq1vq7lrraexwbbqm")

# %% [markdown]
# 数据集信息查看

# %%
from openxlab.dataset import info
info(dataset_repo='OpenDataLab/COIG-CQIA')
# Out:
# +-----------+-----------------------------------------------------------------------------------------------------+
# | Field     | Content                                                                                             |
# +-----------+-----------------------------------------------------------------------------------------------------+
# | Name      | OpenDataLab/COIG-CQIA                                                                               |
# +-----------+-----------------------------------------------------------------------------------------------------+
# | Introduct | 欢迎来到COIG-CQIA，COIG-CQIA全称为Chinese Open Instruction Generalist - Quality is All  You  Need， |
# | ion       | 是一个开源的高质...                                                                                 |
# +-----------+-----------------------------------------------------------------------------------------------------+
# ...

# %% [markdown]
# 数据集文件列表查看

# %%
from openxlab.dataset import query
query(dataset_repo='OpenDataLab/COIG-CQIA')
# Out:
# Total Size: 177.3M
# +--------------------------------------------------------+--------------+
# | File Name                                              | Size         |
# +--------------------------------------------------------+--------------+
# | /zhihu/zhihu_score9.0-10_clean_v10.jsonl               | 0.0B         |
# +--------------------------------------------------------+--------------+
# | /zhihu/zhihu_score8.5-9.0_clean_v4.jsonl               | 3.2M         |
# +--------------------------------------------------------+--------------+
# | /zhihu/zhihu_score8.0-8.5_clean_v3.jsonl               | 3.1M         |
# +--------------------------------------------------------+--------------+
# | /zhihu/zhihu_expansion.jsonl                           | 435.7K       |
# +--------------------------------------------------------+--------------+
# | /xhs/xhs.jsonl                                         | 2.7M         |
# ...
